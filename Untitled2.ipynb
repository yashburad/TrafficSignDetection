# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from keras.utils.np_utils import to_categorical
from keras.layers import Dropout, Flatten
from keras.layers.convolutional import Conv2D, MaxPooling2D
import cv2
from sklearn.model_selection import train_test_split
import pickle
import os
import pandas as pd
from skimage.transform import resize
import random
from sklearn.utils import shuffle
from keras.preprocessing.image import ImageDataGenerator

# %%
path = "myData" # folder with all the class folders
labelFile = 'labels.csv' # file with all names of classes
batch_size_val=50  # how many to process together
steps_per_epoch_val=40
epochs_val=50
imageDimesions = (64,64,3)
testRatio = 0.2    # if 1000 images split will 200 for testing
validationRatio = 0.2 # if 1000 images 20% of remaining 800 will be 160 for validation

# %%
def load_data(directory):
    training_data=[]
    for i in os.listdir(directory):
        if(i[0]=="0"):
            for j in os.listdir(directory+i):
                if j.endswith(".ppm"):
                    training_data.append([cv2.imread(directory+i+"/"+j),int(i)])
    return training_data
        
# Loading the training and testing dataset 
training_data= load_data("Training/")
training_data=shuffle(training_data)
a=np.asarray(training_data)
classNo,images = np.array(list(a[:,1])),np.array(list(a[:,0]))

# %%
resized=[]
for i in images:
    resized.append(resize(i,(64,64), mode ='constant'))
images=np.asarray(resized)

print(images.shape)
# Out:
# (4575, 64, 64, 3)

# %%
X_train, X_validation, y_train, y_validation = train_test_split(images, classNo, test_size=testRatio)
# X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validationRatio)

# %%
print("Data Shapes")
print("Train",end = "");print(X_train.shape,y_train.shape)
print("Validation",end = "");print(X_validation.shape,y_validation.shape)
# print("Test",end = "");print(X_test.shape,y_test.shape)
assert(X_train.shape[0]==y_train.shape[0]), "The number of images in not equal to the number of lables in training set"
assert(X_validation.shape[0]==y_validation.shape[0]), "The number of images in not equal to the number of lables in validation set"
# assert(X_test.shape[0]==y_test.shape[0]), "The number of images in not equal to the number of lables in test set"
assert(X_train.shape[1:]==(imageDimesions))," The dimesions of the Training images are wrong "
assert(X_validation.shape[1:]==(imageDimesions))," The dimesionas of the Validation images are wrong "
# assert(X_test.shape[1:]==(imageDimesions))," The dimesionas of the Test images are wrong"
# Out:
# Data Shapes
# Train(3660, 64, 64, 3) (3660,)
# Validation(915, 64, 64, 3) (915,)

# %%
def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.2989, 0.5870, 0.1140])
def equalize(img):
    img =cv2.equalizeHist(img)
    return img
def preprocessing(img):
    img = rgb2gray(img)     # CONVERT TO GRAYSCALE
    # img = equalize(img)      # STANDARDIZE THE LIGHTING IN AN IMAGE
    # img = img/255            # TO NORMALIZE VALUES BETWEEN 0 AND 1 INSTEAD OF 0 TO 255
    return img

# %%
X_train=np.array(list(map(preprocessing,X_train)))  # TO IRETATE AND PREPROCESS ALL IMAGES
X_validation=np.array(list(map(preprocessing,X_validation)))
# X_test=np.array(list(map(preprocessing,X_test)))
# cv2.imshow("GrayScale Images",X_train[random.randint(0,len(X_train)-1)]) # TO CHECK IF THE TRAINING IS DONE PROPERLY

# %%
X_train=X_train.reshape(X_train.shape[0],X_train.shape[1],X_train.shape[2],1)
X_validation=X_validation.reshape(X_validation.shape[0],X_validation.shape[1],X_validation.shape[2],1)
# X_test=X_test.reshape(X_test.shape[0],X_test.shape[1],X_test.shape[2],1)

# %%
dataGen= ImageDataGenerator(width_shift_range=0.1,   # 0.1 = 10%     IF MORE THAN 1 E.G 10 THEN IT REFFERS TO NO. OF  PIXELS EG 10 PIXELS
                            height_shift_range=0.1,
                            zoom_range=0.2,  # 0.2 MEANS CAN GO FROM 0.8 TO 1.2
                            shear_range=0.1,  # MAGNITUDE OF SHEAR ANGLE
                            rotation_range=10)  # DEGREES
dataGen.fit(X_train)
batches= dataGen.flow(X_train,y_train,batch_size=20)  # REQUESTING DATA GENRATOR TO GENERATE IMAGES  BATCH SIZE = NO. OF IMAGES CREAED EACH TIME ITS CALLED
X_batch,y_batch = next(batches)
 
# TO SHOW AGMENTED IMAGE SAMPLES
fig,axs=plt.subplots(1,15,figsize=(20,5))
fig.tight_layout()
 
for i in range(15):
    axs[i].imshow(X_batch[i].reshape(imageDimesions[0],imageDimesions[1]))
    axs[i].axis('off')
plt.show()

# %%
noOfClasses=62
print(noOfClasses)
y_train = to_categorical(y_train,noOfClasses)
y_validation = to_categorical(y_validation,noOfClasses)
# y_test = to_categorical(y_test,noOfClasses)
# Out:
# 62

# %%
def myModel():
    no_Of_Filters=60
    size_of_Filter=(5,5) # THIS IS THE KERNEL THAT MOVE AROUND THE IMAGE TO GET THE FEATURES.
                         # THIS WOULD REMOVE 2 PIXELS FROM EACH BORDER WHEN USING 32 32 IMAGE
    size_of_Filter2=(3,3)
    size_of_pool=(2,2)  # SCALE DOWN ALL FEATURE MAP TO GERNALIZE MORE, TO REDUCE OVERFITTING
    no_Of_Nodes = 500   # NO. OF NODES IN HIDDEN LAYERS
    model= Sequential()
    model.add((Conv2D(no_Of_Filters,size_of_Filter,input_shape=(imageDimesions[0],imageDimesions[1],1),activation='relu')))  # ADDING MORE CONVOLUTION LAYERS = LESS FEATURES BUT CAN CAUSE ACCURACY TO INCREASE
    model.add((Conv2D(no_Of_Filters, size_of_Filter, activation='relu')))
    model.add(MaxPooling2D(pool_size=size_of_pool)) # DOES NOT EFFECT THE DEPTH/NO OF FILTERS
 
    model.add((Conv2D(no_Of_Filters//2, size_of_Filter2,activation='relu')))
    model.add((Conv2D(no_Of_Filters // 2, size_of_Filter2, activation='relu')))
    model.add(MaxPooling2D(pool_size=size_of_pool))
    model.add(Dropout(0.5))
 
    model.add(Flatten())
    model.add(Dense(no_Of_Nodes,activation='relu'))
    model.add(Dropout(0.5)) # INPUTS NODES TO DROP WITH EACH UPDATE 1 ALL 0 NONE
    model.add(Dense(noOfClasses,activation='softmax')) # OUTPUT LAYER
    # COMPILE MODEL
    model.compile(Adam(lr=0.001),loss='categorical_crossentropy',metrics=['accuracy'])
    return model

# %%
############################### TRAIN
model = myModel()
print(model.summary())
history=model.fit_generator(dataGen.flow(X_train,y_train,batch_size=batch_size_val),steps_per_epoch=steps_per_epoch_val,epochs=epochs_val,validation_data=(X_validation,y_validation),shuffle=1)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_32 (Conv2D)           (None, 60, 60, 60)        1560
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 56, 56, 60)        90060
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 28, 28, 60)        0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 26, 26, 30)        16230
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 24, 24, 30)        8130
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 12, 12, 30)        0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 12, 12, 30)        0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 4320)              0
# _________________________________________________________________
# dense_16 (Dense)             (None, 500)               2160500
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 500)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 62)                31062
# =================================================================
# Total params: 2,307,542
# Trainable params: 2,307,542
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/50
# 40/40 [==============================] - 65s 2s/step - loss: 3.7338 - accuracy: 0.1122 - val_loss: 3.3191 - val_accuracy: 0.2557
# Epoch 2/50
# 40/40 [==============================] - 71s 2s/step - loss: 3.2305 - accuracy: 0.2224 - val_loss: 2.3077 - val_accuracy: 0.4721
# Epoch 3/50
# 40/40 [==============================] - 63s 2s/step - loss: 2.5711 - accuracy: 0.3913 - val_loss: 1.6583 - val_accuracy: 0.5989
# Epoch 4/50
# 40/40 [==============================] - 59s 1s/step - loss: 2.2008 - accuracy: 0.4565 - val_loss: 1.2828 - val_accuracy: 0.6940
# Epoch 5/50
# 40/40 [==============================] - 57s 1s/step - loss: 1.8518 - accuracy: 0.5360 - val_loss: 1.0411 - val_accuracy: 0.7344
# Epoch 6/50
# 40/40 [==============================] - 57s 1s/step - loss: 1.6618 - accuracy: 0.5679 - val_loss: 0.8839 - val_accuracy: 0.7705
# Epoch 7/50
# 40/40 [==============================] - 56s 1s/step - loss: 1.4785 - accuracy: 0.5980 - val_loss: 0.8419 - val_accuracy: 0.8219
# Epoch 8/50
# 40/40 [==============================] - 56s 1s/step - loss: 1.4460 - accuracy: 0.6199 - val_loss: 0.6309 - val_accuracy: 0.8415
# Epoch 9/50
# 40/40 [==============================] - 56s 1s/step - loss: 1.1739 - accuracy: 0.6837 - val_loss: 0.5722 - val_accuracy: 0.8492
# Epoch 10/50
# 40/40 [==============================] - 57s 1s/step - loss: 1.1118 - accuracy: 0.6815 - val_loss: 0.5273 - val_accuracy: 0.8634
# Epoch 11/50
# 40/40 [==============================] - 57s 1s/step - loss: 1.0258 - accuracy: 0.7065 - val_loss: 0.4550 - val_accuracy: 0.8798
# Epoch 12/50
# 40/40 [==============================] - 57s 1s/step - loss: 0.9892 - accuracy: 0.7250 - val_loss: 0.3981 - val_accuracy: 0.8962
# Epoch 13/50
# 40/40 [==============================] - 56s 1s/step - loss: 0.9591 - accuracy: 0.7179 - val_loss: 0.4326 - val_accuracy: 0.8645
# Epoch 14/50
# 40/40 [==============================] - 57s 1s/step - loss: 0.8973 - accuracy: 0.7469 - val_loss: 0.3650 - val_accuracy: 0.9005
# Epoch 15/50
# 40/40 [==============================] - 662s 17s/step - loss: 0.9379 - accuracy: 0.7347 - val_loss: 0.3213 - val_accuracy: 0.9082
# Epoch 16/50
# 40/40 [==============================] - 77s 2s/step - loss: 0.7803 - accuracy: 0.7607 - val_loss: 0.2886 - val_accuracy: 0.9126
# Epoch 17/50
# 40/40 [==============================] - 66s 2s/step - loss: 0.7161 - accuracy: 0.7790 - val_loss: 0.2852 - val_accuracy: 0.9148
# Epoch 18/50
# 40/40 [==============================] - 73s 2s/step - loss: 0.7514 - accuracy: 0.7770 - val_loss: 0.2633 - val_accuracy: 0.9311
# Epoch 19/50
# 40/40 [==============================] - 71s 2s/step - loss: 0.6698 - accuracy: 0.8040 - val_loss: 0.2720 - val_accuracy: 0.9257
# Epoch 20/50
# 40/40 [==============================] - 66s 2s/step - loss: 0.6757 - accuracy: 0.8045 - val_loss: 0.2310 - val_accuracy: 0.9377
# Epoch 21/50
# 40/40 [==============================] - 60s 1s/step - loss: 0.6253 - accuracy: 0.8220 - val_loss: 0.2247 - val_accuracy: 0.9366
# Epoch 22/50
# 40/40 [==============================] - 60s 1s/step - loss: 0.6537 - accuracy: 0.8125 - val_loss: 0.2133 - val_accuracy: 0.9443
# Epoch 23/50
# 40/40 [==============================] - 61s 2s/step - loss: 0.6573 - accuracy: 0.8112 - val_loss: 0.2059 - val_accuracy: 0.9443
# Epoch 24/50
# 40/40 [==============================] - 61s 2s/step - loss: 0.5975 - accuracy: 0.8327 - val_loss: 0.1767 - val_accuracy: 0.9519
# Epoch 25/50
# 40/40 [==============================] - 66s 2s/step - loss: 0.5211 - accuracy: 0.8383 - val_loss: 0.1469 - val_accuracy: 0.9563
# Epoch 26/50
# 40/40 [==============================] - 63s 2s/step - loss: 0.5555 - accuracy: 0.8335 - val_loss: 0.1842 - val_accuracy: 0.9464
# Epoch 27/50
# 40/40 [==============================] - 63s 2s/step - loss: 0.5470 - accuracy: 0.8281 - val_loss: 0.1675 - val_accuracy: 0.9530
# Epoch 28/50
# 40/40 [==============================] - 68s 2s/step - loss: 0.4751 - accuracy: 0.8500 - val_loss: 0.1446 - val_accuracy: 0.9519
# Epoch 29/50
# 40/40 [==============================] - 64s 2s/step - loss: 0.5076 - accuracy: 0.8500 - val_loss: 0.1463 - val_accuracy: 0.9574
# Epoch 30/50
# 40/40 [==============================] - 65s 2s/step - loss: 0.4769 - accuracy: 0.8485 - val_loss: 0.1313 - val_accuracy: 0.9574
# Epoch 31/50
# 40/40 [==============================] - 64s 2s/step - loss: 0.4532 - accuracy: 0.8510 - val_loss: 0.1506 - val_accuracy: 0.9563
# Epoch 32/50
# 40/40 [==============================] - 63s 2s/step - loss: 0.4509 - accuracy: 0.8607 - val_loss: 0.1181 - val_accuracy: 0.9628
# Epoch 33/50
# 40/40 [==============================] - 64s 2s/step - loss: 0.4983 - accuracy: 0.8536 - val_loss: 0.1285 - val_accuracy: 0.9585
# Epoch 34/50
# 40/40 [==============================] - 119s 3s/step - loss: 0.4250 - accuracy: 0.8776 - val_loss: 0.0927 - val_accuracy: 0.9727
# Epoch 35/50
# 40/40 [==============================] - 81s 2s/step - loss: 0.4566 - accuracy: 0.8620 - val_loss: 0.1043 - val_accuracy: 0.9672
# Epoch 36/50
# 40/40 [==============================] - 83s 2s/step - loss: 0.4632 - accuracy: 0.8515 - val_loss: 0.1156 - val_accuracy: 0.9661
# Epoch 37/50
# 40/40 [==============================] - 74s 2s/step - loss: 0.3917 - accuracy: 0.8781 - val_loss: 0.1145 - val_accuracy: 0.9683
# Epoch 38/50
# 40/40 [==============================] - 81s 2s/step - loss: 0.4068 - accuracy: 0.8801 - val_loss: 0.1098 - val_accuracy: 0.9661
# Epoch 39/50
# 40/40 [==============================] - 60s 1s/step - loss: 0.4014 - accuracy: 0.8765 - val_loss: 0.0842 - val_accuracy: 0.9727
# Epoch 40/50
# 40/40 [==============================] - 56s 1s/step - loss: 0.3882 - accuracy: 0.8770 - val_loss: 0.0844 - val_accuracy: 0.9694
# Epoch 41/50
# 40/40 [==============================] - 56s 1s/step - loss: 0.3601 - accuracy: 0.8913 - val_loss: 0.0846 - val_accuracy: 0.9760
# Epoch 42/50
# 40/40 [==============================] - 74s 2s/step - loss: 0.4147 - accuracy: 0.8776 - val_loss: 0.0874 - val_accuracy: 0.9738
# Epoch 43/50
# 40/40 [==============================] - 59s 1s/step - loss: 0.4294 - accuracy: 0.8658 - val_loss: 0.0876 - val_accuracy: 0.9716
# Epoch 44/50
# 40/40 [==============================] - 58s 1s/step - loss: 0.4113 - accuracy: 0.8796 - val_loss: 0.0923 - val_accuracy: 0.9705
# Epoch 45/50
# 40/40 [==============================] - 63s 2s/step - loss: 0.3270 - accuracy: 0.8913 - val_loss: 0.0867 - val_accuracy: 0.9727
# Epoch 46/50
# 40/40 [==============================] - 69s 2s/step - loss: 0.3109 - accuracy: 0.9087 - val_loss: 0.0831 - val_accuracy: 0.9749
# Epoch 47/50
# 40/40 [==============================] - 65s 2s/step - loss: 0.3224 - accuracy: 0.9056 - val_loss: 0.0736 - val_accuracy: 0.9781
# Epoch 48/50
# 40/40 [==============================] - 73s 2s/step - loss: 0.3468 - accuracy: 0.8970 - val_loss: 0.0700 - val_accuracy: 0.9781
# Epoch 49/50
# 40/40 [==============================] - 68s 2s/step - loss: 0.3219 - accuracy: 0.8965 - val_loss: 0.0684 - val_accuracy: 0.9781
# Epoch 50/50
# 40/40 [==============================] - 57s 1s/step - loss: 0.2988 - accuracy: 0.9125 - val_loss: 0.0660 - val_accuracy: 0.9814

# %%
plt.figure(1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['training','validation'])
plt.title('loss')
plt.xlabel('epoch')
plt.figure(2)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['training','validation'])
plt.title('Acurracy')
plt.xlabel('epoch')
plt.show()
score =model.evaluate(X_test,y_test,verbose=0)
print('Test Score:',score[0])
print('Test Accuracy:',score[1])
# Out:
# Test Score: 0.050298891961574554
# Test Accuracy: 0.9868852496147156

# %%
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
from keras.models import model_from_json

json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("model.h5")
print("Loaded model from disk")

# evaluate loaded model on test data
loaded_model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
score = loaded_model.evaluate(X_test,y_test, verbose=0)
print("%s: %.2f%%" % (loaded_model.metrics_names[1], score[1]*100))
# Out:
# Loaded model from disk
# accuracy: 98.69%
