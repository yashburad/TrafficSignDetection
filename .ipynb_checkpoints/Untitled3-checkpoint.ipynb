# %% [markdown]
# **Automatic Traffic Sign Recognition For Automated Car**
#
# **Prof. Ravi Kothari, Machine Learning**
#
# **December 4th, 2020**
#
# **Presented By: Yash Burad, Varsheel Deliwala, Yashvardhan Jain, Siya Jain**

# %% [markdown]
# **This project deals with building a crucial component of driverless cars viz. automatic traffic sign recognition. The model uses the Belgium TS dataset for this purpose.**
#
# The dataset is split into training and testing data and has the following characteristics:
#
# 1.   The image size originally are inconsistent  but then reshaped to 64 (width) x 64 (height) x 3(RGB color channels).
# 2.   The training data set contains 4575 images with 62unique labels.
# 3.   The testing dataset contains 2520 images with 53 unique labels.

# %% [markdown]
# ## **Procedure**

# %% [markdown]
# We import all the libraries that will be required for image augmentation , convolutional neural network, numpy array manipulation and converting images from RGB to gray.

# %%
import skimage
from PIL import Image
import os
import cv2
import skimage.transform
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from skimage.transform import resize
from keras.utils import to_categorical
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from keras.utils.np_utils import to_categorical
from keras.layers import Dropout, Flatten
from keras.layers.convolutional import Conv2D, MaxPooling2D

# %% [markdown]
# The data set is read into an array of array, as follows:
#
# 1. list training_data : a list of [image,image_label] where each image_label represents the label of the image.
#
# 2. list testing_data : a list of [image,image_label] where each image_label represents the label of the image.
#
# We read the data from the "Training/" and "Testing/" directories and use them for the CNN.

# %%
def load_data(directory):
    training_data=[]
    for i in os.listdir(directory):
        if(i[0]=="0"):
            for j in os.listdir(directory+i):
                if j.endswith(".ppm"):
                    training_data.append([cv2.imread(directory+i+"/"+j),int(i)])
    return training_data
        
# Loading the training and testing dataset 
training_data= load_data("Training/")
testing_data = load_data("Testing/")

# %% [markdown]
# ### **Shuffling** ##
#
# Here we shuffle the training and test data to remove biasness and make the dataset more evenly balanced. This help our machine to prevent overfitting. The lack of imbalance could cause our machine to predict the wrong label.

# %%
training_data=shuffle(training_data)
a=np.asarray(training_data)
training_labels,training_images = np.array(list(a[:,1])),np.array(list(a[:,0]))

testing_data=shuffle(testing_data)
a=np.asarray(testing_data)
testing_lables,testing_images = np.array(list(a[:,1])),np.array(list(a[:,0]))

# %% [markdown]
# We see the distribution of the dataset with the labels in the below code and plot a bar graph of the training dataset. We find that the training dataset is highly imbalanced with Label 22 having 375 images and Label 11 having 7 images. We try to tackle this problem later onwards.

# %%
def bar_graph(labels):
    unique_labels = set(labels) #Grouping same labels together
    y_axis=[]
    for label in unique_labels:
        y_axis.append(labels.count(label))
    plt.figure(figsize=(16, 5))
    plt.bar(range(0, len(y_axis)), y_axis)
    plt.title("Distribution of the training dataset")
    plt.xlabel("Class number")
    plt.ylabel("Number of images")
    plt.show()
    
bar_graph(list(training_labels))

# %% [markdown]
# Since the images in the training dataset have different dimensions, we convert every image to 64x64 dimension as working on different dimension would be undesirble for our CNN

# %%
resized=[]
for i in training_images:
    resized.append(resize(i,(64,64), mode ='constant'))
training_images=np.asarray(resized)

resized=[]
for i in testing_images:
    resized.append(resize(i,(64,64), mode ='constant'))
testing_images=np.asarray(resized)

# %%
print(training_images.shape)
# Out:
# (4575, 64, 64, 3)

# %% [markdown]
# We just print one image from each label from the training dataset along with the number of images present for that label

# %%
def display_images(labels,images): 
    setLabels = set(labels) 
    plt.figure(figsize=(15, 15))
    i = 1
    for label in setLabels:
        image = images[labels.index(label)]
        plt.subplot(7, 10, i)
        plt.axis('off')
        plt.title("Label "+str(label)+"("+str(labels.count(label))+")")
        plt.imshow(image)
        i += 1
    plt.show()
    
display_images(list(training_labels),training_images)

# %% [markdown]
# ### **Splitting** ###
#
# Now we split it testing data into 80:20 ratio to testing and validation data.We will be using the validation dataset in our model learning and testing dataset to find the accuracy of the model on the testing dataset

# %%
testing_images, validation_images, testing_labels, validation_labels = train_test_split(testing_images,testing_lables, test_size=0.2)

# print(testing_images.shape)
# print(testing_labels.shape)

# print(validation_images.shape)
# print(validation_labels.shape)

# %% [markdown]
# We convert our 3 channel (RGB) images (32 x 32 x 3) into a grayscale image (32 x 32 x1). We implement gray scaling of the images on all the datasets to check if grayscaling help us in removing noise from our dataset and make our CNN model more efficient

# %%
def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.2989, 0.5870, 0.1140])

training_images=np.array(list(map(rgb2gray,training_images)))  
validation_images=np.array(list(map(rgb2gray,validation_images)))
testing_images=np.array(list(map(rgb2gray,testing_images)))

# %%
display_images(list(training_labels),training_images) #display the converted images

# %%
# Adding a depth of 1 to eack dataset to make dimension of every image to (64,64,1)

training_images=training_images.reshape(training_images.shape[0],training_images.shape[1],
                                        training_images.shape[2],1)
validation_images=validation_images.reshape(validation_images.shape[0],validation_images.shape[1],
                                            validation_images.shape[2],1)
testing_images=testing_images.reshape(testing_images.shape[0],testing_images.shape[1],
                                      testing_images.shape[2],1)

# %% [markdown]
# ### **Data Augmentation**
#
# Now, In the initial training dataset we can see that:
#
# *   Label 22 has 375 images.
# *   Label 11 has 7 images.
#
# We see that the initial dataset has the problem of class imbalance. We try to solve this imbalance and give our dataset different types of input using **data augmentation** to make our model more robust.
#
# We use the following image augmentation to try to make up for the imbalance:
#
# 1. Random Rotation between -100 and 100 angles
# 2. Changes Zoom_range and shear_range of the images and set it 0.25 and 0.15 respectively. 0.25 can imply 0.75 to 1.25.
# 3. Width_shift_range & Height_shift_range : Set to 0.15. Width_shift actually shift the image to the left or right(horizontal shifts) by 15% and height_shift vertically by 15%.

# %%
imageDimensions = (64,64,1)

dataFit= ImageDataGenerator(rotation_range=10, # rotation degrees - -10 to 10
                            width_shift_range=0.15,   # 0.15 = 15%
                            height_shift_range=0.15,
                            zoom_range=0.25,  # 0.25 means it can go from 0.75 TO 1.25
                            shear_range=0.15) # value of the shear angle 

dataFit.fit(training_images) #this does data augmentation on our training dataset

# %% [markdown]
# We implement one hot encoding. A one hot encoding allows the representation of categorical data to be more expressive.

# %%
classes=len(set(training_labels))
training_labels = to_categorical(training_labels,classes)
validation_labels = to_categorical(validation_labels,classes)
testing_labels = to_categorical(testing_labels,classes)

# print(len(set(training_labels)))

# %% [markdown]
# ## Convolutional Neural Network ##
#
# We implement a model which has four layers of feature - 64,64,32 and 32. All of the feature layer uses relu as the activation function. We keep the size of the filter at (5,5) and (3,3). We use adam optimizer to compile the model.

# %%
def myModel():
    model= Sequential()
    model.add((Conv2D(64,(5,5),padding='same',input_shape=(imageDimensions[0],imageDimensions[1],1),activation='relu')))
    model.add((Conv2D(64, (5,5),padding='same', activation='relu')))
    model.add(MaxPooling2D(pool_size=(2,2))) 
 
    model.add((Conv2D(32, (3,3), padding='same',activation='relu')))
    model.add((Conv2D(32, (3,3),padding='same', activation='relu')))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.5))
 
    model.add(Flatten())
    model.add(Dense(512,activation='relu'))
    model.add(Dropout(0.5)) 
    model.add(Dense(classes,activation='softmax')) 
    # COMPILE MODEL
    model.compile(Adam(lr=0.001),loss='categorical_crossentropy',metrics=['accuracy'])
    return model

# %%
batchSize=50
epochsVal=50
stepsPerEpoch=50

model = myModel()
print(model.summary())
history=model.fit_generator(dataGen.flow(training_images,training_labels,batch_size=batchSize),
                            steps_per_epoch=stepsPerEpoch,epochs=epochsVal,
                            validation_data=(validation_images,validation_labels),shuffle=1,verbose=1)
# Out:
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_56 (Conv2D)           (None, 64, 64, 64)        1664
# _________________________________________________________________
# conv2d_57 (Conv2D)           (None, 64, 64, 64)        102464
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_58 (Conv2D)           (None, 32, 32, 32)        18464
# _________________________________________________________________
# conv2d_59 (Conv2D)           (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_29 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 16, 16, 32)        0
# _________________________________________________________________
# flatten_14 (Flatten)         (None, 8192)              0
# _________________________________________________________________
# dense_34 (Dense)             (None, 512)               4194816
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_35 (Dense)             (None, 62)                31806
# =================================================================
# Total params: 4,358,462
# Trainable params: 4,358,462
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/50
# 50/50 [==============================] - 106s 2s/step - loss: 3.7423 - accuracy: 0.0893 - val_loss: 3.5958 - val_accuracy: 0.1786
# Epoch 2/50
# 50/50 [==============================] - 105s 2s/step - loss: 3.4787 - accuracy: 0.1584 - val_loss: 2.9951 - val_accuracy: 0.3413
# Epoch 3/50
# 50/50 [==============================] - 106s 2s/step - loss: 2.9188 - accuracy: 0.2780 - val_loss: 2.2430 - val_accuracy: 0.4762
# Epoch 4/50
# 50/50 [==============================] - 105s 2s/step - loss: 2.5419 - accuracy: 0.3523 - val_loss: 1.9898 - val_accuracy: 0.4940
# Epoch 5/50
# 50/50 [==============================] - 126s 3s/step - loss: 2.2656 - accuracy: 0.4048 - val_loss: 1.7907 - val_accuracy: 0.5040
# Epoch 6/50
# 50/50 [==============================] - 138s 3s/step - loss: 2.0300 - accuracy: 0.4747 - val_loss: 1.4067 - val_accuracy: 0.6567
# Epoch 7/50
# 50/50 [==============================] - 108s 2s/step - loss: 1.8408 - accuracy: 0.4994 - val_loss: 1.2969 - val_accuracy: 0.6667
# Epoch 8/50
# 50/50 [==============================] - 118s 2s/step - loss: 1.7606 - accuracy: 0.5257 - val_loss: 1.0808 - val_accuracy: 0.7282
# Epoch 9/50
# 50/50 [==============================] - 120s 2s/step - loss: 1.5499 - accuracy: 0.5762 - val_loss: 0.9949 - val_accuracy: 0.7183
# Epoch 10/50
# 50/50 [==============================] - 137s 3s/step - loss: 1.3975 - accuracy: 0.6072 - val_loss: 0.9705 - val_accuracy: 0.7401
# Epoch 11/50
# 50/50 [==============================] - 140s 3s/step - loss: 1.3170 - accuracy: 0.6307 - val_loss: 0.8401 - val_accuracy: 0.7679
# Epoch 12/50
# 50/50 [==============================] - 132s 3s/step - loss: 1.1863 - accuracy: 0.6684 - val_loss: 0.7341 - val_accuracy: 0.7877
# Epoch 13/50
# 50/50 [==============================] - 138s 3s/step - loss: 1.1111 - accuracy: 0.6780 - val_loss: 0.7245 - val_accuracy: 0.7758
# Epoch 14/50
# 50/50 [==============================] - 118s 2s/step - loss: 1.0559 - accuracy: 0.6900 - val_loss: 0.6680 - val_accuracy: 0.8254
# Epoch 15/50
# 50/50 [==============================] - 117s 2s/step - loss: 1.0180 - accuracy: 0.7063 - val_loss: 0.5771 - val_accuracy: 0.8571
# Epoch 16/50
# 50/50 [==============================] - 134s 3s/step - loss: 0.9336 - accuracy: 0.7289 - val_loss: 0.6235 - val_accuracy: 0.7837
# Epoch 17/50
# 50/50 [==============================] - 136s 3s/step - loss: 0.8984 - accuracy: 0.7324 - val_loss: 0.5335 - val_accuracy: 0.8472
# Epoch 18/50
# 50/50 [==============================] - 116s 2s/step - loss: 0.8724 - accuracy: 0.7398 - val_loss: 0.4670 - val_accuracy: 0.8571
# Epoch 19/50
# 50/50 [==============================] - 111s 2s/step - loss: 0.8181 - accuracy: 0.7536 - val_loss: 0.4151 - val_accuracy: 0.8948
# Epoch 20/50
# 50/50 [==============================] - 104s 2s/step - loss: 0.7487 - accuracy: 0.7778 - val_loss: 0.4163 - val_accuracy: 0.8948
# Epoch 21/50
# 50/50 [==============================] - 109s 2s/step - loss: 0.7407 - accuracy: 0.7864 - val_loss: 0.3543 - val_accuracy: 0.9107
# Epoch 22/50
# 50/50 [==============================] - 105s 2s/step - loss: 0.7333 - accuracy: 0.7879 - val_loss: 0.3788 - val_accuracy: 0.8889
# Epoch 23/50
# 50/50 [==============================] - 105s 2s/step - loss: 0.6754 - accuracy: 0.7980 - val_loss: 0.3787 - val_accuracy: 0.9028
# Epoch 24/50
# 50/50 [==============================] - 101s 2s/step - loss: 0.6604 - accuracy: 0.8129 - val_loss: 0.3368 - val_accuracy: 0.9107
# Epoch 25/50
# 50/50 [==============================] - 93s 2s/step - loss: 0.6445 - accuracy: 0.8113 - val_loss: 0.2956 - val_accuracy: 0.9147
# Epoch 26/50
# 50/50 [==============================] - 97s 2s/step - loss: 0.6439 - accuracy: 0.8113 - val_loss: 0.2966 - val_accuracy: 0.9306
# Epoch 27/50
# 50/50 [==============================] - 94s 2s/step - loss: 0.6166 - accuracy: 0.8192 - val_loss: 0.3123 - val_accuracy: 0.9048
# Epoch 28/50
# 50/50 [==============================] - 108s 2s/step - loss: 0.5858 - accuracy: 0.8272 - val_loss: 0.2778 - val_accuracy: 0.9226
# Epoch 29/50
# 50/50 [==============================] - 98s 2s/step - loss: 0.5663 - accuracy: 0.8268 - val_loss: 0.2970 - val_accuracy: 0.9187
# Epoch 30/50
# 50/50 [==============================] - 103s 2s/step - loss: 0.5950 - accuracy: 0.8263 - val_loss: 0.3011 - val_accuracy: 0.9087
# Epoch 31/50
# 50/50 [==============================] - 107s 2s/step - loss: 0.5236 - accuracy: 0.8444 - val_loss: 0.2306 - val_accuracy: 0.9484
# Epoch 32/50
# 50/50 [==============================] - 110s 2s/step - loss: 0.4901 - accuracy: 0.8549 - val_loss: 0.2346 - val_accuracy: 0.9345
# Epoch 33/50
# 50/50 [==============================] - 106s 2s/step - loss: 0.5388 - accuracy: 0.8343 - val_loss: 0.2607 - val_accuracy: 0.9266
# Epoch 34/50
# 50/50 [==============================] - 104s 2s/step - loss: 0.5003 - accuracy: 0.8525 - val_loss: 0.2987 - val_accuracy: 0.9246
# Epoch 35/50
# 50/50 [==============================] - 114s 2s/step - loss: 0.4983 - accuracy: 0.8448 - val_loss: 0.2392 - val_accuracy: 0.9444
# Epoch 36/50
# 50/50 [==============================] - 97s 2s/step - loss: 0.4821 - accuracy: 0.8586 - val_loss: 0.2620 - val_accuracy: 0.9405
# Epoch 37/50
# 50/50 [==============================] - 93s 2s/step - loss: 0.4994 - accuracy: 0.8509 - val_loss: 0.2217 - val_accuracy: 0.9484
# Epoch 38/50
# 50/50 [==============================] - 94s 2s/step - loss: 0.4402 - accuracy: 0.8716 - val_loss: 0.2186 - val_accuracy: 0.9544
# Epoch 39/50
# 50/50 [==============================] - 92s 2s/step - loss: 0.4544 - accuracy: 0.8602 - val_loss: 0.2298 - val_accuracy: 0.9464
# Epoch 40/50
# 50/50 [==============================] - 93s 2s/step - loss: 0.4511 - accuracy: 0.8592 - val_loss: 0.2552 - val_accuracy: 0.9385
# Epoch 41/50
# 50/50 [==============================] - 94s 2s/step - loss: 0.4377 - accuracy: 0.8592 - val_loss: 0.2376 - val_accuracy: 0.9504
# Epoch 42/50
# 50/50 [==============================] - 94s 2s/step - loss: 0.4576 - accuracy: 0.8668 - val_loss: 0.2086 - val_accuracy: 0.9484
# Epoch 43/50
# 50/50 [==============================] - 93s 2s/step - loss: 0.4403 - accuracy: 0.8687 - val_loss: 0.2557 - val_accuracy: 0.9365
# Epoch 44/50
# 50/50 [==============================] - 217s 4s/step - loss: 0.4254 - accuracy: 0.8704 - val_loss: 0.2621 - val_accuracy: 0.9345
# Epoch 45/50
# 50/50 [==============================] - 104s 2s/step - loss: 0.4309 - accuracy: 0.8622 - val_loss: 0.2381 - val_accuracy: 0.9345
# Epoch 46/50
# 50/50 [==============================] - 93s 2s/step - loss: 0.4114 - accuracy: 0.8788 - val_loss: 0.1993 - val_accuracy: 0.9524
# Epoch 47/50
# 50/50 [==============================] - 94s 2s/step - loss: 0.3836 - accuracy: 0.8840 - val_loss: 0.2079 - val_accuracy: 0.9484
# Epoch 48/50
# 50/50 [==============================] - 108s 2s/step - loss: 0.3755 - accuracy: 0.8868 - val_loss: 0.2169 - val_accuracy: 0.9484
# Epoch 49/50
# 50/50 [==============================] - 118s 2s/step - loss: 0.3886 - accuracy: 0.8820 - val_loss: 0.1701 - val_accuracy: 0.9683
# Epoch 50/50
# 50/50 [==============================] - 181s 4s/step - loss: 0.3782 - accuracy: 0.8880 - val_loss: 0.2044 - val_accuracy: 0.9603

# %%
plt.figure(1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['training','validation'])
plt.title('Accuracy')
plt.xlabel('epoch')
plt.figure(2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['training','validation'])
plt.title('Loss')
plt.xlabel('epoch')
plt.show()
score =model.evaluate(testing_images,testing_labels,verbose=0)
print('Test Score:',score[0])
print('Test Accuracy:',score[1])
# Out:
# Test Score: 0.18245789408683777
# Test Accuracy: 0.9598214030265808

# %%
test_predictions = model.predict_classes(testing_images, batch_size=batchSize, verbose =1)
# Out:
# 41/41 [==============================] - 18s 433ms/step

# %%
from sklearn.metrics import confusion_matrix

values=[]
for i in range(testing_labels.shape[0]):
    for j in range(0,62):
        if(testing_labels[i][j]==1):
            values.append(j)

cm_test = confusion_matrix(values, test_predictions)
cm_test = cm_test.astype('float') / cm_test.sum(axis=1)[:, np.newaxis]  #To nomalize the confusion matrix
# Out:
# <ipython-input-213-354d58ef7a2d>:10: RuntimeWarning: invalid value encountered in true_divide
#   cm_test = cm_test.astype('float') / cm_test.sum(axis=1)[:, np.newaxis]  #To nomalize the confusion matrix

# %%
import seaborn as sns
f = plt.figure(figsize=(40,20))
ax=f.add_subplot(1,1,1)
sns.heatmap(cm_test, linewidths=1, square = True, cmap = 'Blues')
ax.set_title('Confusion Matrix');
ax.set_ylabel('Correct label')
ax.set_xlabel('CNN Predicted label')
plt.show()

# %% [markdown]
# ## Saving and Loading the Model ##

# %%
# https://machinelearningmastery.com/save-load-keras-deep-learning-models/

model_json = model.to_json()
with open("model1.json", "w") as json_file:
    json_file.write(model_json)
    
model.save_weights("model1.h5")
print("Saved the cnn model to disk")
# Out:
# Saved the cnn model to disk

# %%
# https://machinelearningmastery.com/save-load-keras-deep-learning-models/
from keras.models import model_from_json

json_file = open('model1.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("model1.h5")
print("Loaded model from disk")

# evaluate loaded model on test data
loaded_model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
score = loaded_model.evaluate(testing_images,testing_labels, verbose=0)
print("%s: %.2f%%" % (loaded_model.metrics_names[1], score[1]*100))
# Out:
# Loaded model from disk
# accuracy: 95.59%
